# %% [markdown]
# ### 1. Load the Enviromental Variables

# %%
SHARED_FS = 'tpushare'
MOUNT_POINT = '/mnt/common'
TPU_POD_NAME = 'nyc-tpu-v3-32' 
NFS_IP = '10.224.68.26'
BUILD = '5e452b42-a97c-40da-9a1a-5f2a5fc6ba34'
PYTORCH_PROJ_NAME='pytorch-tpu-nfs'

# %% [markdown]
# ### 2. Load data from GCS bucket

# %%
GCS_DATASET='gs://tpu-demo-eu/dataset/*'
# !if [ -d "$MOUNT_POINT/data" ]; then echo "using existing $MOUNT_POINT/data directory"; else sudo mkdir -p $MOUNT_POINT/data && sudo gsutil -m cp -r ${_GCS_DATASET} $MOUNT_POINT/data/; fi
# Out:
# using existing /data directory

# %% [markdown]
# ### 3. Download RoBERTa code from repo

# %%
CODE_REPO='https://github.com/taylanbil/fairseq.git'
BRANCH='roberta-tpu'
# !if [ -d "$MOUNT_POINT/code" ]; then echo "using existing $MOUNT_POINT/code directory"; else sudo mkdir -p $MOUNT_POINT/code && sudo git clone ${_CODE_REPO} $MOUNT_POINT/code/; fi
# !cd $MOUNT_POINT/code/ && git fetch && git checkout $BRANCH
# Out:
# using existing /code directory
# Already on 'roberta-tpu'
# Your branch is up-to-date with 'origin/roberta-tpu'.

# %% [markdown]
# ### 4. Set the execution Variables

# %%
logfile = "$(date +%Y%m%d)-roberta-podrun-$1.txt"
nshards = 1
num_cores = 8
data_path = "$MOUNT_POINT/data" 
DATABIN = '/mnt/common/data/shard0'
checkpoints_out = MOUNT_POINT+'/checkpoints/checkpoints-roberta'+BUILD

# %% [markdown]
# ### Execute torch_xla.distributed.xla_dist

# %%
# !python -m torch_xla.distributed.xla_dist --tpu=$TPU_POD_NAME \
	--docker-run-flag=--shm-size=50GB \
	--docker-run-flag=--rm=true \
	--docker-run-flag=--volume=$SHARED_FS:$MOUNT_POINT \
	--env=XLA_USE_BF16=1  \
	--docker-image=gcr.io/$PYTORCH_PROJ_NAME/xla:$BUILD -- python $MOUNT_POINT/code/train.py \
	$DATABIN \
	--save-dir $checkpoints_out \
	--arch roberta_large \
	--optimizer adam \
	--adam-betas "(0.9, 0.98)" \
	--adam-eps 1e-06 \
	--clip-norm 1.0 \
	--lr-scheduler polynomial_decay \
	--lr 0.0004 \
	--warmup-updates 15000 \
	--max-update 1500000 \
	--log-format json \
	--log-interval 10 \
	--skip-invalid-size-inputs-valid-test \
	--task multilingual_masked_lm \
	--criterion masked_lm \
	--dropout 0.1 \
	--attention-dropout 0.1 \
	--weight-decay 0.01 \
	--sample-break-mode complete \
	--tokens-per-sample 512 \
	--total-num-update 1500000 \
	--multilang-sampling-alpha 0.7 \
	--no-epoch-checkpoints \
	--save-interval-updates 3000 \
	--validate-interval 5000 \
	--num-workers 1 \
	--update-freq `expr 4096 / 8` \
	--valid-subset=valid \
	--train-subset=train \
	--input_shapes 2x512 \
	--num_cores=8 \
	--metrics_debug \
	--suppress_loss_report \
	--log_steps=1
# Out:
# 2020-04-20 20:57:19  [] Command to distribute: "python" "/mnt/common/code/train.py" "/mnt/common/data/shard0" "--save-dir" "/mnt/common/checkpoints/checkpoints-roberta5e452b42-a97c-40da-9a1a-5f2a5fc6ba34" "--arch" "roberta_large" "--optimizer" "adam" "--adam-betas" "(0.9, 0.98)" "--adam-eps" "1e-06" "--clip-norm" "1.0" "--lr-scheduler" "polynomial_decay" "--lr" "0.0004" "--warmup-updates" "15000" "--max-update" "1500000" "--log-format" "json" "--log-interval" "10" "--skip-invalid-size-inputs-valid-test" "--task" "multilingual_masked_lm" "--criterion" "masked_lm" "--dropout" "0.1" "--attention-dropout" "0.1" "--weight-decay" "0.01" "--sample-break-mode" "complete" "--tokens-per-sample" "512" "--total-num-update" "1500000" "--multilang-sampling-alpha" "0.7" "--no-epoch-checkpoints" "--save-interval-updates" "3000" "--validate-interval" "5000" "--num-workers" "1" "--update-freq" "512" "--valid-subset=valid" "--train-subset=train" "--input_shapes" "2x512" "--num_cores=8" "--metrics_debug" "--suppress_loss_report" "--log_steps=1"
# 2020-04-20 20:57:19  [] Cluster configuration: {client_workers: [{10.164.15.217, n1-standard-16, europe-west4-a, nyc-tpu-slave-407n}, {10.164.15.219, n1-standard-16, europe-west4-a, nyc-tpu-slave-7nwh}, {10.164.15.218, n1-standard-16, europe-west4-a, nyc-tpu-slave-kzr6}, {10.164.15.220, n1-standard-16, europe-west4-a, nyc-tpu-slave-mkrg}], service_workers: [{10.3.0.4, 8470, v3-32, europe-west4-a, pytorch-nightly, nyc-tpu-v3-32}, {10.3.0.5, 8470, v3-32, europe-west4-a, pytorch-nightly, nyc-tpu-v3-32}, {10.3.0.2, 8470, v3-32, europe-west4-a, pytorch-nightly, nyc-tpu-v3-32}, {10.3.0.3, 8470, v3-32, europe-west4-a, pytorch-nightly, nyc-tpu-v3-32}]}
# 2020-04-20 20:57:21 10.164.15.217 [0]   % Total    % Received % Xferd  Average Speed   Time    Time     Time  Current
# 2020-04-20 20:57:21 10.164.15.217 [0]                                  Dload  Upload   Total   Spent    Left  Speed
# 100    19  100    19    0     0   3800      0 --:--:-- --:--:-- --:--:--  3800
# 2020-04-20 20:57:23 10.164.15.217 [0]   % Total    % Received % Xferd  Average Speed   Time    Time     Time  Current
# 2020-04-20 20:57:23 10.164.15.217 [0]                                  Dload  Upload   Total   Spent    Left  Speed
# 100    19  100    19    0     0   3800      0 --:--:-- --:--:-- --:--:--  3800
# 2020-04-20 20:57:26 10.164.15.218 [2]   % Total    % Received % Xferd  Average Speed   Time    Time     Time  Current
# 2020-04-20 20:57:26 10.164.15.218 [2]                                  Dload  Upload   Total   Spent    Left  Speed
# 2020-04-20 20:57:26 10.164.15.220 [3]   % Total    % Received % Xferd  Average Speed   Time    Time     Time  Current
# 2020-04-20 20:57:26 10.164.15.220 [3]                                  Dload  Upload   Total   Spent    Left  Speed
# 100    19  100    19    0     0   2714      0 --:--:-- --:--:-- --:--:--  3166
# 100    19  100    19    0     0   3166      0 --:--:-- --:--:-- --:--:--  3166
# 2020-04-20 20:57:26 10.164.15.219 [1]   % Total    % Received % Xferd  Average Speed   Time    Time     Time  Current
# 2020-04-20 20:57:26 10.164.15.219 [1]                                  Dload  Upload   Total   Spent    Left  Speed
# 100    19  100    19    0     0   2714      0 --:--:-- --:--:-- --:--:--  2714
# 2020-04-20 20:57:29 10.164.15.218 [2]   % Total    % Received % Xferd  Average Speed   Time    Time     Time  Current
# 2020-04-20 20:57:29 10.164.15.218 [2]                                  Dload  Upload   Total   Spent    Left  Speed
# 100    19  100    19    0     0   3166      0 --:--:-- --:--:-- --:--:--  3166
# 2020-04-20 20:57:29 10.164.15.220 [3]   % Total    % Received % Xferd  Average Speed   Time    Time     Time  Current
# 2020-04-20 20:57:29 10.164.15.220 [3]                                  Dload  Upload   Total   Spent    Left  Speed
# 100    19  100    19    0     0   3166      0 --:--:-- --:--:-- --:--:--  3166
# 2020-04-20 20:57:29 10.164.15.219 [1]   % Total    % Received % Xferd  Average Speed   Time    Time     Time  Current
# 2020-04-20 20:57:29 10.164.15.219 [1]                                  Dload  Upload   Total   Spent    Left  Speed
# 100    19  100    19    0     0   3166      0 --:--:-- --:--:-- --:--:--  3166
# 2020-04-20 20:57:32 10.164.15.218 [2]   % Total    % Received % Xferd  Average Speed   Time    Time     Time  Current
# 2020-04-20 20:57:32 10.164.15.218 [2]                                  Dload  Upload   Total   Spent    Left  Speed
# 100    19  100    19    0     0   3166      0 --:--:-- --:--:-- --:--:--  3166
# 2020-04-20 20:57:32 10.164.15.217 [0]   % Total    % Received % Xferd  Average Speed   Time    Time     Time  Current
# 2020-04-20 20:57:32 10.164.15.217 [0]                                  Dload  Upload   Total   Spent    Left  Speed
# 100    19  100    19    0     0   3166      0 --:--:-- --:--:-- --:--:--  3166
# 2020-04-20 20:57:32 10.164.15.220 [3]   % Total    % Received % Xferd  Average Speed   Time    Time     Time  Current
# 2020-04-20 20:57:32 10.164.15.220 [3]                                  Dload  Upload   Total   Spent    Left  Speed
# 100    19  100    19    0     0   3166      0 --:--:-- --:--:-- --:--:--  3166
# 2020-04-20 20:57:32 10.164.15.219 [1]   % Total    % Received % Xferd  Average Speed   Time    Time     Time  Current
# 2020-04-20 20:57:32 10.164.15.219 [1]                                  Dload  Upload   Total   Spent    Left  Speed
# 100    19  100    19    0     0   3166      0 --:--:-- --:--:-- --:--:--  3166
# 2020-04-20 20:57:37 10.164.15.217 [0] suppressing distributed_init args for GPU
# 2020-04-20 20:57:38 10.164.15.217 [0] 2020-04-20 20:57:38.540760: I      13 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:38 10.164.15.217 [0] 2020-04-20 20:57:38.540760: I      17 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:38 10.164.15.217 [0] 2020-04-20 20:57:38.540760: I      18 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:38 10.164.15.217 [0] 2020-04-20 20:57:38.540760: I      16 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:38 10.164.15.217 [0] 2020-04-20 20:57:38.540760: I      19 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:38 10.164.15.217 [0] 2020-04-20 20:57:38.540775: I      15 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:38 10.164.15.217 [0] 2020-04-20 20:57:38.540779: I      14 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:44 10.164.15.217 [0] WARNING: bfloat16 is enabled. Note that fairseq meters such as loss will accumulate the numerator, and increment the denominator. Due to lack of precision in higher numbers in bfloat16, these meters will report invalid values after a while.
# 2020-04-20 20:57:44 10.164.15.217 [0] Args
# 2020-04-20 20:57:44 10.164.15.217 [0] 	no_progress_bar False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	log_interval None
# 2020-04-20 20:57:44 10.164.15.217 [0] 	log_format json
# 2020-04-20 20:57:44 10.164.15.217 [0] 	tensorboard_logdir
# 2020-04-20 20:57:44 10.164.15.217 [0] 	tbmf_wrapper False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	seed 1
# 2020-04-20 20:57:44 10.164.15.217 [0] 	cpu False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	fp16 False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	memory_efficient_fp16 False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	fp16_init_scale 128
# 2020-04-20 20:57:44 10.164.15.217 [0] 	fp16_scale_window None
# 2020-04-20 20:57:44 10.164.15.217 [0] 	fp16_scale_tolerance 0.0
# 2020-04-20 20:57:44 10.164.15.217 [0] 	min_loss_scale 0.0001
# 2020-04-20 20:57:44 10.164.15.217 [0] 	threshold_loss_scale None
# 2020-04-20 20:57:44 10.164.15.217 [0] 	user_dir None
# 2020-04-20 20:57:44 10.164.15.217 [0] 	empty_cache_freq 0
# 2020-04-20 20:57:44 10.164.15.217 [0] 	criterion masked_lm
# 2020-04-20 20:57:44 10.164.15.217 [0] 	tokenizer None
# 2020-04-20 20:57:44 10.164.15.217 [0] 	bpe None
# 2020-04-20 20:57:44 10.164.15.217 [0] 	optimizer adam
# 2020-04-20 20:57:44 10.164.15.217 [0] 	lr_scheduler polynomial_decay
# 2020-04-20 20:57:44 10.164.15.217 [0] 	task multilingual_masked_lm
# 2020-04-20 20:57:44 10.164.15.217 [0] 	num_workers 1
# 2020-04-20 20:57:44 10.164.15.217 [0] 	skip_invalid_size_inputs_valid_test True
# 2020-04-20 20:57:44 10.164.15.217 [0] 	max_tokens None
# 2020-04-20 20:57:44 10.164.15.217 [0] 	max_sentences None
# 2020-04-20 20:57:44 10.164.15.217 [0] 	required_batch_size_multiple 8
# 2020-04-20 20:57:44 10.164.15.217 [0] 	dataset_impl None
# 2020-04-20 20:57:44 10.164.15.217 [0] 	train_subset train
# 2020-04-20 20:57:44 10.164.15.217 [0] 	valid_subset valid
# 2020-04-20 20:57:44 10.164.15.217 [0] 	validate_interval 5000
# 2020-04-20 20:57:44 10.164.15.217 [0] 	fixed_validation_seed None
# 2020-04-20 20:57:44 10.164.15.217 [0] 	disable_validation False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	max_tokens_valid None
# 2020-04-20 20:57:44 10.164.15.217 [0] 	max_sentences_valid None
# 2020-04-20 20:57:44 10.164.15.217 [0] 	curriculum 0
# 2020-04-20 20:57:44 10.164.15.217 [0] 	distributed_world_size 1
# 2020-04-20 20:57:44 10.164.15.217 [0] 	distributed_rank 0
# 2020-04-20 20:57:44 10.164.15.217 [0] 	distributed_backend nccl
# 2020-04-20 20:57:44 10.164.15.217 [0] 	distributed_init_method None
# 2020-04-20 20:57:44 10.164.15.217 [0] 	distributed_port -1
# 2020-04-20 20:57:44 10.164.15.217 [0] 	device_id 0
# 2020-04-20 20:57:44 10.164.15.217 [0] 	distributed_no_spawn False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	ddp_backend c10d
# 2020-04-20 20:57:44 10.164.15.217 [0] 	bucket_cap_mb 25
# 2020-04-20 20:57:44 10.164.15.217 [0] 	fix_batches_to_gpus False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	find_unused_parameters False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	fast_stat_sync False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	arch roberta_large
# 2020-04-20 20:57:44 10.164.15.217 [0] 	max_epoch 0
# 2020-04-20 20:57:44 10.164.15.217 [0] 	max_update 1500000
# 2020-04-20 20:57:44 10.164.15.217 [0] 	clip_norm 1.0
# 2020-04-20 20:57:44 10.164.15.217 [0] 	sentence_avg False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	update_freq [512]
# 2020-04-20 20:57:44 10.164.15.217 [0] 	lr [0.0004]
# 2020-04-20 20:57:44 10.164.15.217 [0] 	min_lr -1
# 2020-04-20 20:57:44 10.164.15.217 [0] 	use_bmuf False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	save_dir /mnt/common/checkpoints/checkpoints-roberta5e452b42-a97c-40da-9a1a-5f2a5fc6ba34
# 2020-04-20 20:57:44 10.164.15.217 [0] 	restore_file checkpoint_last.pt
# 2020-04-20 20:57:44 10.164.15.217 [0] 	reset_dataloader False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	reset_lr_scheduler False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	reset_meters False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	reset_optimizer False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	optimizer_overrides {}
# 2020-04-20 20:57:44 10.164.15.217 [0] 	save_interval 1
# 2020-04-20 20:57:44 10.164.15.217 [0] 	save_interval_updates 3000
# 2020-04-20 20:57:44 10.164.15.217 [0] 	keep_interval_updates -1
# 2020-04-20 20:57:44 10.164.15.217 [0] 	keep_last_epochs -1
# 2020-04-20 20:57:44 10.164.15.217 [0] 	no_save False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	no_epoch_checkpoints True
# 2020-04-20 20:57:44 10.164.15.217 [0] 	no_last_checkpoints False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	no_save_optimizer_state False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	best_checkpoint_metric loss
# 2020-04-20 20:57:44 10.164.15.217 [0] 	maximize_best_checkpoint_metric False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	input_shapes [[2, 512]]
# 2020-04-20 20:57:44 10.164.15.217 [0] 	log_steps 1
# 2020-04-20 20:57:44 10.164.15.217 [0] 	num_cores 8
# 2020-04-20 20:57:44 10.164.15.217 [0] 	metrics_debug True
# 2020-04-20 20:57:44 10.164.15.217 [0] 	use_gpu False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	target_train_loss None
# 2020-04-20 20:57:44 10.164.15.217 [0] 	target_valid_loss None
# 2020-04-20 20:57:44 10.164.15.217 [0] 	suppress_loss_report True
# 2020-04-20 20:57:44 10.164.15.217 [0] 	encoder_layerdrop 0
# 2020-04-20 20:57:44 10.164.15.217 [0] 	encoder_layers_to_keep None
# 2020-04-20 20:57:44 10.164.15.217 [0] 	adam_betas (0.9, 0.98)
# 2020-04-20 20:57:44 10.164.15.217 [0] 	adam_eps 1e-06
# 2020-04-20 20:57:44 10.164.15.217 [0] 	weight_decay 0.01
# 2020-04-20 20:57:44 10.164.15.217 [0] 	force_anneal None
# 2020-04-20 20:57:44 10.164.15.217 [0] 	warmup_updates 15000
# 2020-04-20 20:57:44 10.164.15.217 [0] 	end_learning_rate 0.0
# 2020-04-20 20:57:44 10.164.15.217 [0] 	power 1.0
# 2020-04-20 20:57:44 10.164.15.217 [0] 	total_num_update 1500000
# 2020-04-20 20:57:44 10.164.15.217 [0] 	data /mnt/common/data/shard0
# 2020-04-20 20:57:44 10.164.15.217 [0] 	sample_break_mode complete
# 2020-04-20 20:57:44 10.164.15.217 [0] 	tokens_per_sample 512
# 2020-04-20 20:57:44 10.164.15.217 [0] 	mask_prob 0.15
# 2020-04-20 20:57:44 10.164.15.217 [0] 	leave_unmasked_prob 0.1
# 2020-04-20 20:57:44 10.164.15.217 [0] 	random_token_prob 0.1
# 2020-04-20 20:57:44 10.164.15.217 [0] 	freq_weighted_replacement False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	mask_whole_words False
# 2020-04-20 20:57:44 10.164.15.217 [0] 	multilang_sampling_alpha 0.7
# 2020-04-20 20:57:44 10.164.15.217 [0] 	dropout 0.1
# 2020-04-20 20:57:44 10.164.15.217 [0] 	attention_dropout 0.1
# 2020-04-20 20:57:44 10.164.15.217 [0] 	encoder_layers 24
# 2020-04-20 20:57:44 10.164.15.217 [0] 	encoder_embed_dim 1024
# 2020-04-20 20:57:44 10.164.15.217 [0] 	encoder_ffn_embed_dim 4096
# 2020-04-20 20:57:44 10.164.15.217 [0] 	encoder_attention_heads 16
# 2020-04-20 20:57:44 10.164.15.217 [0] 	activation_fn gelu
# 2020-04-20 20:57:44 10.164.15.217 [0] 	pooler_activation_fn tanh
# 2020-04-20 20:57:44 10.164.15.217 [0] 	activation_dropout 0.0
# 2020-04-20 20:57:44 10.164.15.217 [0] 	pooler_dropout 0.0
# 2020-04-20 20:57:44 10.164.15.217 [0] 	max_source_positions 512
# 2020-04-20 20:57:44 10.164.15.217 [0] Exception in device=TPU:0: [Errno 2] No such file or directory: '/mnt/common/data/shard0/dict.txt'
# 2020-04-20 20:57:44 10.164.15.217 [0] Traceback (most recent call last):
# 2020-04-20 20:57:44 10.164.15.217 [0]   File "/root/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch_xla/distributed/xla_multiprocessing.py", line 119, in _start_fn
# 2020-04-20 20:57:44 10.164.15.217 [0]     fn(gindex, *args)
# 2020-04-20 20:57:44 10.164.15.217 [0]   File "/mnt/common/code/train.py", line 712, in _mp_fn
# 2020-04-20 20:57:44 10.164.15.217 [0]     main_tpu(args)
# 2020-04-20 20:57:44 10.164.15.217 [0]   File "/mnt/common/code/train.py", line 533, in main_tpu
# 2020-04-20 20:57:44 10.164.15.217 [0]     args, xla_device)
# 2020-04-20 20:57:44 10.164.15.217 [0]   File "/mnt/common/code/train.py", line 389, in prepare_task
# 2020-04-20 20:57:44 10.164.15.217 [0]     task = tasks.setup_task(args)
# 2020-04-20 20:57:44 10.164.15.217 [0]   File "/mnt/common/code/fairseq/tasks/__init__.py", line 17, in setup_task
# 2020-04-20 20:57:44 10.164.15.217 [0]     return TASK_REGISTRY[args.task].setup_task(args, **kwargs)
# 2020-04-20 20:57:44 10.164.15.217 [0]   File "/mnt/common/code/fairseq/tasks/multilingual_masked_lm.py", line 74, in setup_task
# 2020-04-20 20:57:44 10.164.15.217 [0]     dictionary = Dictionary.load(os.path.join(paths[0], 'dict.txt'))
# 2020-04-20 20:57:44 10.164.15.217 [0]   File "/mnt/common/code/fairseq/data/dictionary.py", line 188, in load
# 2020-04-20 20:57:44 10.164.15.217 [0]     d.add_from_file(f, ignore_utf_errors)
# 2020-04-20 20:57:44 10.164.15.217 [0]   File "/mnt/common/code/fairseq/data/dictionary.py", line 205, in add_from_file
# 2020-04-20 20:57:44 10.164.15.217 [0]     raise fnfe
# 2020-04-20 20:57:44 10.164.15.217 [0]   File "/mnt/common/code/fairseq/data/dictionary.py", line 199, in add_from_file
# 2020-04-20 20:57:44 10.164.15.217 [0]     with open(f, 'r', encoding='utf-8') as fd:
# 2020-04-20 20:57:44 10.164.15.217 [0] FileNotFoundError: [Errno 2] No such file or directory: '/mnt/common/data/shard0/dict.txt'
# 2020-04-20 20:57:44 10.164.15.217 [0] Traceback (most recent call last):
# 2020-04-20 20:57:44 10.164.15.217 [0]   File "/mnt/common/code/train.py", line 716, in <module>
# 2020-04-20 20:57:44 10.164.15.217 [0]     cli_main()
# 2020-04-20 20:57:44 10.164.15.217 [0]   File "/mnt/common/code/train.py", line 707, in cli_main
# 2020-04-20 20:57:44 10.164.15.217 [0]     xmp.spawn(_mp_fn, args=(args,), nprocs=args.num_cores)
# 2020-04-20 20:57:44 10.164.15.217 [0]   File "/root/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch_xla/distributed/xla_multiprocessing.py", line 182, in spawn
# 2020-04-20 20:57:44 10.164.15.217 [0]     start_method=start_method)
# 2020-04-20 20:57:44 10.164.15.217 [0]   File "/root/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/multiprocessing/spawn.py", line 158, in start_processes
# 2020-04-20 20:57:44 10.164.15.217 [0]     while not context.join():
# 2020-04-20 20:57:44 10.164.15.217 [0]   File "/root/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/multiprocessing/spawn.py", line 113, in join
# 2020-04-20 20:57:44 10.164.15.217 [0]     (error_index, exitcode)
# 2020-04-20 20:57:44 10.164.15.217 [0] Exception: process 0 terminated with exit code 17
# 2020-04-20 20:57:49 10.164.15.218 [2] suppressing distributed_init args for GPU
# 2020-04-20 20:57:49 10.164.15.219 [1] suppressing distributed_init args for GPU
# 2020-04-20 20:57:49 10.164.15.220 [3] suppressing distributed_init args for GPU
# 2020-04-20 20:57:50 10.164.15.218 [2] 2020-04-20 20:57:50.901913: I      12 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:50 10.164.15.218 [2] 2020-04-20 20:57:50.914662: I      14 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:50 10.164.15.218 [2] 2020-04-20 20:57:50.916378: I      16 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:50 10.164.15.218 [2] 2020-04-20 20:57:50.919722: I      18 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:50 10.164.15.218 [2] 2020-04-20 20:57:50.924414: I      13 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:50 10.164.15.218 [2] 2020-04-20 20:57:50.947354: I      19 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:50 10.164.15.220 [3] 2020-04-20 20:57:50.959788: I      14 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:50 10.164.15.220 [3] 2020-04-20 20:57:50.959773: I      15 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:50 10.164.15.220 [3] 2020-04-20 20:57:50.961870: I      16 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:50 10.164.15.219 [1] 2020-04-20 20:57:50.962604: I      12 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:50 10.164.15.219 [1] 2020-04-20 20:57:50.962604: I      17 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:50 10.164.15.219 [1] 2020-04-20 20:57:50.962588: I      13 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:50 10.164.15.220 [3] 2020-04-20 20:57:50.970297: I      12 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:50 10.164.15.219 [1] 2020-04-20 20:57:50.974386: I      14 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:50 10.164.15.220 [3] 2020-04-20 20:57:50.980634: I      17 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:50 10.164.15.219 [1] 2020-04-20 20:57:50.983777: I      15 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:50 10.164.15.219 [1] 2020-04-20 20:57:50.989066: I      16 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:50 10.164.15.220 [3] 2020-04-20 20:57:50.992555: I      18 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:51 10.164.15.218 [2] 2020-04-20 20:57:51.003406: I      17 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:51 10.164.15.218 [2] 2020-04-20 20:57:51.009626: I      15 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:51 10.164.15.219 [1] 2020-04-20 20:57:51.013060: I      19 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:51 10.164.15.219 [1] 2020-04-20 20:57:51.018160: I      18 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:51 10.164.15.220 [3] 2020-04-20 20:57:51.022975: I      19 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
# 2020-04-20 20:57:51 10.164.15.220 [3] 2020-04-20 20:57:51.034711: I      13 tensorflow/compiler/xla/xla_client/mesh_service.cc:212] Waiting to connect to client mesh master (300 seconds) 10.164.15.217:8477
